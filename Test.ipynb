# %% [markdown]
# Importing Customer and Orders Dataset

# %%
import pandas as pd

df = pd.read_csv("./DataSet/orders.csv")
print(df.to_string())
# Out:
#     Order_id  Customer_id          Product_name  Quantity  Unit_price
# 0          1            1            Yard Short         1       89.93
# 1          2           26       Commercial With         1       52.91
# 2          3           36          Hair Teacher         4       42.77
# 3          4           45              To Their        10       53.63
# 4          5           37    Traditional Region         6       69.01
# 5          6           38          Receive Save         1       59.80
# 6          7           29        Research Visit         8       63.91
# 7          8            5             Pick Fast         3       76.86
# 8          9           18  Explain Organization        10       76.30
# 9         10           46               Eat Boy         3       70.84
# 10        11           36              Six Bill        10       78.73
# 11        12           12          Sister Heart         4       22.61
# ...

# %%
import pandas as pd

df = pd.read_csv("./DataSet/customers.csv")
print(df.to_string())
# Out:
#     Customer_id First_name    Surname                        Email     Status
# 0             1       Paul       Ryan          znorris@example.com   archived
# 1             2     Monica      Jones   sierrarobinson@example.net   archived
# 2             3    Heather    Collins       franksmith@example.com   archived
# 3             4    Kristin      Olson   hernandezchase@example.org  suspended
# 4             5   Patricia     Holmes       hallnicole@example.com     active
# 5             6     Rachel       Vang      arnoldpeter@example.com  suspended
# 6             7      Angel   Gonzalez      francisco70@example.net   archived
# 7             8    Dorothy     Larson          mtaylor@example.org   archived
# 8             9     Sheryl     Jensen            phill@example.net   archived
# 9            10    Natasha     Torres          david51@example.net     active
# 10           11     Joseph      Davis           lwelch@example.com  suspended
# ...
